# %%
import pandas as pd

# %%
data = pd.read_json("Data.json")
data.head(5)
# Out:
#    id       city  budget_min  budget_max  smoking  drinking     food  \
# 0   1  Bangalore        8000       18000    False     False  non-veg
# 1   2  Bangalore        9000       16000    False      True  non-veg
# 2   3       Pune        7000       14000    False     False      veg
# 3   4  Hyderabad        8500       17000     True      True  non-veg
# 4   5     Mumbai       10000       20000    False     False      veg
#
#   sleep_schedule  cleanliness_level work_style                personality  \
# 0         normal                  4     office       Quiet and thoughtful
# 1           late                  3     hybrid        Outgoing and social
# 2          early                  5     office  Disciplined and organized
# 3           late                  2     remote       Casual and laid-back
# 4         normal                  4     office       Friendly and helpful
#
#                                      lifestyle_notes  \
# 0    Enjoys yoga and cooking. Prefers calm mornings.
# 1     Loves music and weekend hangouts with friends.
# 2     Marathon runner, strict routine, home by 9 PM.
# 3  Works odd hours, game enthusiast, enjoys poker...
# 4  Volunteers on weekends, loves reading, early s...
#
#                   roommate_expectations
# 0         Respectful, quiet after 10 PM
# 1     Someone open to occasional guests
# 2         Clean, structured, non-smoker
# 3   Flexible person, doesn't mind noise
# 4  Honest, reliable, values cleanliness

# %%
new_user = {
  "id": 12,
  "city": "Bangalore",
  "budget_min": 9000,
  "budget_max": 13000,
  "smoking": "false",
  "drinking": "true",
  "food": "non-veg",
  "sleep_schedule": "early",
  "cleanliness_level": 4,
  "work_style": "hybrid",
  "personality": "Calm and organized, prefers quiet evenings",
  "lifestyle_notes": "Works weekdays, enjoys reading and light workouts",
  "roommate_expectations": "Looking for someone clean, respectful, and non-smoker"
}

# %%
def find_matching_users(old_users_df: pd.DataFrame, new_user: dict) -> pd.DataFrame:
    filtered_df = old_users_df.copy()
    # 1. City match (mandatory)
    filtered_df = filtered_df[
        filtered_df["city"].str.lower() == new_user["city"].lower()
    ]
    # 2. Food preference match
    filtered_df = filtered_df[
        filtered_df["food"].str.lower() == new_user["food"].lower()
    ]

    return filtered_df.reset_index(drop=True)

# %%
filtered_Roommates = find_matching_users(data,new_user)
filtered_Roommates
# Out:
#     id       city  budget_min  budget_max  smoking  drinking     food  \
# 0    1  Bangalore        8000       18000    False     False  non-veg
# 1    2  Bangalore        9000       16000    False      True  non-veg
# 2    6  Bangalore        9500       19000    False      True  non-veg
# 3    8  Bangalore        8000       15000    False     False  non-veg
# 4   13  Bangalore        8000       14000    False     False  non-veg
# 5   16  Bangalore        9000       16000     True      True  non-veg
# 6   19  Bangalore       10000       19000    False      True  non-veg
# 7   22  Bangalore        8500       16000    False     False  non-veg
# 8   29  Bangalore        8500       15000    False      True  non-veg
# 9   32  Bangalore        9500       17500    False     False  non-veg
# 10  34  Bangalore        8000       13000     True      True  non-veg
# 11  39  Bangalore        9000       15500    False     False  non-veg
# 12  44  Bangalore        9500       16500    False      True  non-veg
# 13  50  Bangalore        8500       15000    False     False  non-veg
#
#    sleep_schedule  cleanliness_level work_style                   personality  \
# 0          normal                  4     office          Quiet and thoughtful
# 1            late                  3     hybrid           Outgoing and social
# 2          normal                  3     hybrid  Ambitious and career-focused
# 3            late                  3     remote      Creative and spontaneous
# 4           early                  3    student        Energetic and friendly
# 5            late                  2     office    Fun-loving and adventurous
# 6            late                  3     hybrid     Ambitious startup founder
# 7            late                  2     remote           Introspective coder
# 8          normal                  3     hybrid              Creative thinker
# 9           early                  4     office        Focused and determined
# 10           late                  1     remote           Carefree minimalist
# 11           late                  3     remote     Ambitious content creator
# 12           late                  3     office           Fun and spontaneous
# 13         normal                  3     hybrid        Balanced and pragmatic
#
#                                       lifestyle_notes  \
# 0     Enjoys yoga and cooking. Prefers calm mornings.
# 1      Loves music and weekend hangouts with friends.
# 2   Fitness enthusiast, works long hours, weekends...
# 3   Freelance designer, irregular hours, coffee ad...
# 4   MBA student, morning person, occasional study ...
# 5   Works in startup, frequent travel, casual abou...
# 6   Passionate entrepreneur, works irregular hours...
# 7   Systems engineer, works nights, minimalist lif...
# 8    UX designer, artistic, weekend gallery explorer.
# 9   Management consultant, frequent traveler, valu...
# 10       Freelancer, lives light, irregular schedule.
# 11  YouTuber, requires quiet for recording, flexib...
# 12  Event organizer, loves adventures, impromptu t...
# 13  Product manager, values work-life balance, enj...
#
#                             roommate_expectations
# 0                   Respectful, quiet after 10 PM
# 1               Someone open to occasional guests
# 2            Independent person, respects privacy
# 3          Understanding about irregular schedule
# 4   Supportive, doesn't mind academic discussions
# 5             Flexible, adventure-seeking partner
# 6            Understands startup hustle mentality
# 7        Respects alone time, minimal interaction
# 8             Appreciates creativity, open-minded
# 9            Respectful, keeps common areas clean
# 10         Non-judgmental about lifestyle choices
# 11             Understands content creation needs
# 12            Adventurous spirit, flexible person
# 13        Balanced person, respects shared spaces

# %%
def build_embedding_text(user: dict) -> str:
    return (
        f"Personality: {user.get('personality', '')}. "
        f"Lifestyle: {user.get('lifestyle_notes', '')}. "
        f"Roommate expectations: {user.get('roommate_expectations', '')}."
    ).strip()

embedding_texts = []

for _, row in filtered_Roommates.iterrows():
    user_dict = row.to_dict()
    text = build_embedding_text(user_dict)
    embedding_texts.append(text)

embedding_texts
# Out:
# ['Personality: Quiet and thoughtful. Lifestyle: Enjoys yoga and cooking. Prefers calm mornings.. Roommate expectations: Respectful, quiet after 10 PM.',
#  'Personality: Outgoing and social. Lifestyle: Loves music and weekend hangouts with friends.. Roommate expectations: Someone open to occasional guests.',
#  'Personality: Ambitious and career-focused. Lifestyle: Fitness enthusiast, works long hours, weekends for relaxation.. Roommate expectations: Independent person, respects privacy.',
#  'Personality: Creative and spontaneous. Lifestyle: Freelance designer, irregular hours, coffee addict.. Roommate expectations: Understanding about irregular schedule.',
#  "Personality: Energetic and friendly. Lifestyle: MBA student, morning person, occasional study groups at home.. Roommate expectations: Supportive, doesn't mind academic discussions.",
#  'Personality: Fun-loving and adventurous. Lifestyle: Works in startup, frequent travel, casual about home management.. Roommate expectations: Flexible, adventure-seeking partner.',
#  'Personality: Ambitious startup founder. Lifestyle: Passionate entrepreneur, works irregular hours, brainstorms at odd times.. Roommate expectations: Understands startup hustle mentality.',
#  'Personality: Introspective coder. Lifestyle: Systems engineer, works nights, minimalist lifestyle.. Roommate expectations: Respects alone time, minimal interaction.',
#  'Personality: Creative thinker. Lifestyle: UX designer, artistic, weekend gallery explorer.. Roommate expectations: Appreciates creativity, open-minded.',
#  'Personality: Focused and determined. Lifestyle: Management consultant, frequent traveler, values home time.. Roommate expectations: Respectful, keeps common areas clean.',
#  'Personality: Carefree minimalist. Lifestyle: Freelancer, lives light, irregular schedule.. Roommate expectations: Non-judgmental about lifestyle choices.',
#  'Personality: Ambitious content creator. Lifestyle: YouTuber, requires quiet for recording, flexible schedule.. Roommate expectations: Understands content creation needs.',
#  'Personality: Fun and spontaneous. Lifestyle: Event organizer, loves adventures, impromptu trips.. Roommate expectations: Adventurous spirit, flexible person.',
#  'Personality: Balanced and pragmatic. Lifestyle: Product manager, values work-life balance, enjoys reading.. Roommate expectations: Balanced person, respects shared spaces.']

# %%
vectors = model.encode(
    embedding_texts,
    convert_to_numpy=True,
    normalize_embeddings=True
)

# %%
import faiss

dimension = vectors.shape[1]

index = faiss.IndexFlatIP(dimension)  # cosine similarity
index.add(vectors.astype("float32"))

print("Total vectors in index:", index.ntotal)
# Out:
# Total vectors in index: 14

# %%
id_map = filtered_Roommates["id"].tolist()
id_map
# Out:
# [1, 2, 6, 8, 13, 16, 19, 22, 29, 32, 34, 39, 44, 50]

# %%
new_user_text = build_embedding_text(new_user)

new_user_vector = model.encode(
    [new_user_text],
    convert_to_numpy=True,
    normalize_embeddings=True
).astype("float32")

# %%
TOP_K = 3

scores, indices = index.search(new_user_vector, TOP_K)

# %%
vector_results = []

for rank, idx in enumerate(indices[0]):
    vector_results.append({
        "userId": id_map[idx],
        "score": float(scores[0][rank])
    })
vector_results
# Out:
# [{'userId': 2, 'score': 0.8959038257598877},
#  {'userId': 6, 'score': 0.8538482189178467},
#  {'userId': 32, 'score': 0.8498193025588989}]

# %%
candidate_ids = [r["userId"] for r in vector_results]

candidates = filtered_Roommates[
    filtered_Roommates["id"].isin(candidate_ids)
].to_dict(orient="records")



candidate_ids
# Out:
# [2, 6, 32]
